# %% [markdown]
# <a href="https://colab.research.google.com/github/YHVang/Extern-Google-Colab/blob/master/Extern_Build_a_Simple_Chatbot_with_LlamaIndex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U google-genai llama-index llama-index-llms-google-genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 724.2/724.2 kB 20.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 1.61.0
#     Uninstalling google-genai-1.61.0:
#       Successfully uninstalled google-genai-1.61.0
# ...

# %%
import os
import nest_asyncio
nest_asyncio.apply()

GOOGLE_API_KEY = "AIzaSyA7rXzpsHjxtM5mFo3smVixNpB6tJ1MTBw"  # Replace with your actual API key
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

# %%
from llama_index.llms.google_genai import GoogleGenAI
from llama_index.core.llms import ChatMessage

llm = GoogleGenAI(model="models/gemini-2.5-flash")


from llama_index.llms.google_genai import GoogleGenAI
from llama_index.core.llms import ChatMessage
import os

llm = GoogleGenAI(
    model="models/gemini-2.5-flash"
)

def simple_chatbot():
    print("A Simple Gemini Chatbot")
    print("Type 'exit' to end the conversation")
    print("-" * 50)

    messages = []

    while True:
        user_input = input("\nYou: ")

        if user_input.lower() in ["exit", "quit", "bye"]:
            print("\nChatbot: Goodbye! Have a great day")
            break

        messages.append(ChatMessage(role="user", content=user_input))

        response = llm.chat(messages)

        assistant_reply = response.message.content
        print(f"\nChatbot: {assistant_reply}")

        messages.append(
            ChatMessage(role="assistant", content=assistant_reply)
        )

# %%
# Run the Chatbot
if __name__ == "__main__":
  simple_chatbot()
# Out:
# A Simple Gemini Chatbot
# Type 'exit' to end the conversation
# --------------------------------------------------
#
# Chatbot: Hello! How can I help you today?
#
# Chatbot: I can definitely help you with that, but Minnesota is a big state! The weather can vary quite a bit from one region to another.
#
# To give you the most accurate forecast, could you please tell me which **city or specific area** in Minnesota you're interested in?
#
# Chatbot: Okay, let's get you the weather for **Saint Paul, Minnesota**!
#
# Here's a summary of what to expect:
#
# **Current Conditions (as of my last update):**
# *   **Temperature:** Around 60-65°F (16-18°C)
# *   **Conditions:** Mostly sunny to partly cloudy.
# *   **Wind:** Light breeze.
#
# **Today (Wednesday, May 29th):**
# *   **High:** Expect it to reach the **mid-70s°F (around 24-26°C)**.
# *   **Conditions:** Mostly sunny with some scattered clouds. It will be a pleasant and warm day.
# *   **Precipitation:** Very low chance of rain.
#
# ...
